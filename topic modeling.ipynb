# %%
import pandas as pd
import re
import numpy as np
import pandas as pd

# %%
vape_general=pd.read_csv('C:/Users/arnav/Downloads/final_data.csv')
vape_general.head()
# Out:
#                      threadname            threaddate threaduser  \
# 0  need help with mixing liquid  2019-10-24T14:19:16Z     dbster
# 1  need help with mixing liquid  2019-10-24T14:19:16Z     dbster
# 2  need help with mixing liquid  2019-10-24T14:19:16Z     dbster
# 3  need help with mixing liquid  2019-10-24T14:19:16Z     dbster
# 4  need help with mixing liquid  2019-10-24T14:19:16Z     dbster
#
#    threadreplies   username                       date  posts  \
# 0              5       Walt  2019-10-24 23:41:41+00:00    800
# 1              5        Tam  2019-10-25 01:57:33+00:00   4489
# 2              5  adamabbot  2019-11-19 22:14:36+00:00      5
# 3              5        Tam  2019-11-20 01:27:54+00:00   4489
# 4              5  adamabbot  2019-11-27 20:30:01+00:00      5
#
#                                              comment
# 0                                        hey welcome
# 1  addition advise walt gave back store ask buy f...
# 2  thanks answer also interested good mix may rec...
# 3  mix whatever flavor want whether taste good an...
# 4                                         thanks tam

# %%
text_data=[str(i).split(' ') for i in list(vape_general["comment"].values)]
text_data[:5]
# Out:
# [['hey', 'welcome'],
#  ['addition',
#   'advise',
#   'walt',
#   'gave',
#   'back',
#   'store',
#   'ask',
#   'buy',
#   'flavoring',
#   'polypropylene',
#   'glycol',
#   'delivers',
#   'throat',
#   'hit',
#   'well',
#   'higher',
#   'nic',
#   'content',
#   'adding',
#   'existing',
#   'juice',
#   'thin',
#   'also',
#   'dilute',
#   'flavor',
#   'bit',
#   'adding',
#   'liquid',
#   'may',
#   'notice',
#   'get',
#   'little',
#   'le',
#   'vapor',
#   'add',
#   'flavor',
#   'carrier',
#   'thinner',
#   'make',
#   'juice',
#   'sweeter',
#   'mellows',
#   'throat',
#   'hit',
#   'make',
#   'smoother',
#   'give',
#   'vapor',
#   'might',
#   'help'],
#  ['thanks',
#   'answer',
#   'also',
#   'interested',
#   'good',
#   'mix',
#   'may',
#   'recommend',
#   'know',
#   'mix',
#   'interested',
#   'taste',
#   'mix'],
#  ['mix',
#   'whatever',
#   'flavor',
#   'want',
#   'whether',
#   'taste',
#   'good',
#   'another',
#   'matter',
#   'taste',
#   'subjective',
#   'taste',
#   'great',
#   'one',
#   'person',
#   'may',
#   'taste',
#   'like',
#   'wet',
#   'sock',
#   'another',
#   'way',
#   'know',
#   'like',
#   'try'],
#  ['thanks', 'tam']]

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from gensim) (1.16.4)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from gensim) (1.3.3)
# Requirement already satisfied: six>=1.5.0 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from gensim) (1.9.0)
# Requirement already satisfied: boto3 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from smart-open>=1.8.1->gensim) (1.9.246)
# Requirement already satisfied: requests in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: boto>=2.32 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.246 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.12.246)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from botocore<1.13.0,>=1.12.246->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in c:\users\arnav\appdata\local\continuum\anaconda2\lib\site-packages (from botocore<1.13.0,>=1.12.246->boto3->smart-open>=1.8.1->gensim) (2.8.0)

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.016*"day" + 0.016*"vaping" + 0.015*"time" + 0.014*"one"')
# (1, '0.025*"vapor" + 0.022*"get" + 0.021*"taste" + 0.019*"flavor"')
# (2, '0.026*"know" + 0.025*"thanks" + 0.020*"would" + 0.018*"guy"')
# (3, '0.068*"battery" + 0.031*"ego" + 0.018*"mod" + 0.018*"one"')
# (4, '0.046*"cartos" + 0.034*"vapor" + 0.027*"talk" + 0.019*"water"')
# (5, '0.032*"juice" + 0.026*"flavor" + 0.022*"like" + 0.020*"order"')
# (6, '0.024*"tank" + 0.023*"cart" + 0.022*"atomizer" + 0.020*"drip"')
# (7, '0.065*"nice" + 0.042*"cool" + 0.040*"glad" + 0.035*"sound"')
# (8, '0.037*"post" + 0.031*"video" + 0.030*"forum" + 0.028*"review"')
# (9, '0.066*"ecigs" + 0.059*"awesome" + 0.045*"wow" + 0.040*"http"')
